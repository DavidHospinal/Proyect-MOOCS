# %%
import pandas as pd
import numpy as np
import ast

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Mooc.csv')

df.head()
# Out:
#                                          NombreCurso  CantidadVentas  \
# 0  Programming for Everybody (Getting Started wit...             234
# 1  Programming for Everybody (Getting Started wit...             489
# 2  Programming for Everybody (Getting Started wit...             416
# 3  Programming for Everybody (Getting Started wit...             673
# 4  Programming for Everybody (Getting Started wit...             876
#
#               Institucion                               UrlCurso IdCurso  \
# 0  University of Michigan  https://www.coursera.org/learn/python  python
# 1  University of Michigan  https://www.coursera.org/learn/python  python
# 2  University of Michigan  https://www.coursera.org/learn/python  python
# 3  University of Michigan  https://www.coursera.org/learn/python  python
# 4  University of Michigan  https://www.coursera.org/learn/python  python
#
#    FechaCurso  Puntuacion  Precio   Idioma         Nivel Plataforma  \
# ...

# %%
import pandas as pd

# Actualizar los valores en la columna "CantidadVentas" de la plataforma "Coursera"
df.loc[df['Plataforma'] == 'Coursera', 'CantidadVentas'] = 1

print(df)
# Out:
#                                               NombreCurso  CantidadVentas  \
# 0       Programming for Everybody (Getting Started wit...               1
# 1       Programming for Everybody (Getting Started wit...               1
# 2       Programming for Everybody (Getting Started wit...               1
# 3       Programming for Everybody (Getting Started wit...               1
# 4       Programming for Everybody (Getting Started wit...               1
# ...                                                   ...             ...
# 523346             Designing and Leading Learning Systems           11895
# 523347                      Proteins: Biology's Workforce           25893
# 523348     Using GPUs to Scale and Speed-up Deep Learning            9294
# 523349  Computational Neuroscience: Neuronal Dynamics ...           11246
# 523350  Cities and the Challenge of Sustainable Develo...            8775
#
#                    Institucion  \
# 0       University of Michigan
# ...

# %%
df.head()
# Out:
#                                          NombreCurso  CantidadVentas  \
# 0  Programming for Everybody (Getting Started wit...               1
# 1  Programming for Everybody (Getting Started wit...               1
# 2  Programming for Everybody (Getting Started wit...               1
# 3  Programming for Everybody (Getting Started wit...               1
# 4  Programming for Everybody (Getting Started wit...               1
#
#               Institucion                               UrlCurso IdCurso  \
# 0  University of Michigan  https://www.coursera.org/learn/python  python
# 1  University of Michigan  https://www.coursera.org/learn/python  python
# 2  University of Michigan  https://www.coursera.org/learn/python  python
# 3  University of Michigan  https://www.coursera.org/learn/python  python
# 4  University of Michigan  https://www.coursera.org/learn/python  python
#
#    FechaCurso  Puntuacion  Precio   Idioma         Nivel Plataforma  \
# ...

# %%
import pandas as pd

# Actualizar la columna "Ventas" con la multiplicación de "Precio" y "CantidadVentas"
df['Ventas'] = df['Precio'] * df['CantidadVentas']

print(df)
# Out:
#                                               NombreCurso  CantidadVentas  \
# 0       Programming for Everybody (Getting Started wit...               1
# 1       Programming for Everybody (Getting Started wit...               1
# 2       Programming for Everybody (Getting Started wit...               1
# 3       Programming for Everybody (Getting Started wit...               1
# 4       Programming for Everybody (Getting Started wit...               1
# ...                                                   ...             ...
# 523346             Designing and Leading Learning Systems           11895
# 523347                      Proteins: Biology's Workforce           25893
# 523348     Using GPUs to Scale and Speed-up Deep Learning            9294
# 523349  Computational Neuroscience: Neuronal Dynamics ...           11246
# 523350  Cities and the Challenge of Sustainable Develo...            8775
#
#                    Institucion  \
# 0       University of Michigan
# ...

# %%
df = df[df['Idioma'] != '中文']

# %%
import pandas as pd


# Contar la cantidad de cada tipo de datos en la columna 'Idioma'
print(df['Idioma'].value_counts())

# Ver los tipos de datos únicos en la columna 'Idioma'
print(df['Idioma'].unique())
# Out:
# English     87835
# Français    87366
# Chino       87151
# Deutsch     87130
# Español     87112
# Italiano    86756
# Name: Idioma, dtype: int64
# ['Español' 'English' 'Deutsch' 'Italiano' 'Chino' 'Français']

# %%
#Exportando:
# Especifica la ruta y el nombre de archivo para guardar el dataset convertido
ruta_archivo_convertido = '/content/drive/MyDrive/Mooc1.csv.csv'

# Exporta el DataFrame con la columna convertida al archivo CSV
df.to_csv(ruta_archivo_convertido, index=False)

# %%
df.columns
# Out:
# Index(['NombreCurso', 'CantidadVentas', 'Institucion', 'UrlCurso', 'IdCurso',
#        'FechaCurso', 'Puntuacion', 'Precio', 'Idioma', 'Nivel', 'Plataforma',
#        'CursoPaga', 'Tematica', 'Ventas'],
#       dtype='object')

# %%
# Contar la cantidad de cada tipo de datos en la columna 'Idioma'
print(df['Idioma'].value_counts())

# Ver los tipos de datos únicos en la columna 'Idioma'
print(df['Idioma'].unique())

# %%
print(df['Nivel'].value_counts())
print(df['Nivel'].unique())
# Out:
# Introductory          173990
# Advanced              172935
# Intermediate          172753
# All Levels              1925
# Beginner Level          1268
# Intermediate Level       421
# Expert Level              58
# Name: Nivel, dtype: int64
# ['Introductory' 'Intermediate' 'Advanced' 'All Levels' 'Beginner Level'
#  'Intermediate Level' 'Expert Level']
